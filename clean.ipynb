# %% [markdown]
# Importamos pandaspara cargar el archivo .csv

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("attacks.csv",encoding="latin1")

# %%
print(df.shape)
# Out:
# (25723, 24)

# %%
df.head(15)
df2 =pd.DataFrame(df)
df2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
for e in df.columns:
    print(e)
# Out:
# Case Number
# Date
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Injury
# Fatal (Y/N)
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %% [markdown]
# Miramos la columna de numero de "Case Number","Year".

# %%
#Elijo estoas dos columnas que son las que voy a usar como referencia para mi hipotesis
casosyear= df2[["Case Number","Year"]]
casosyear
df2["Case Number"].value_counts()
# Out:
# 0               2400
# 1913.08.27.R       2
# 2014.08.02         2
# 2009.12.18         2
# 1990.05.10         2
#                 ...
# 1995.09.03.a       1
# 1989.01.03         1
# 1959.11.10         1
# 1959.10.02         1
# 2014.08.01         1
# Name: Case Number, Length: 6287, dtype: int64

# %%
#Limpiamos los duplicados
limpito = df.drop_duplicates()
limpito
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 6307               NaN  NaN  ...              NaN
# 6308               NaN  NaN  ...              NaN
# 6309               NaN  NaN  ...              NaN
# 8702               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 6307                              NaN                       NaN
# 6308                              NaN                       NaN
# 6309                              NaN                       NaN
# 8702                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 6307                                                 NaN           NaN
# 6308                                                 NaN           NaN
# 6309                                                 NaN           NaN
# 8702                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 6307            NaN         6309.0         NaN         NaN
# 6308            NaN         6310.0         NaN         NaN
# 6309            NaN            NaN         NaN         NaN
# 8702            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [6312 rows x 24 columns]

# %% [markdown]
# creo que hay varias columnas iguales

# %%
def comparar(x,d):
    for e in x:
        for c in d:
            if e == c:
                
                return True
            else:
                
                return False
            
comparar(limpito["Case Number"],limpito["Case Number.1"])
# Out:
# True

# %%
comparar(limpito["href formula"],limpito["href"])
# Out:
# True

# %%
comparar (limpito["Case Number"],limpito["Case Number.2"])
# Out:
# True

# %%
#Dropeamos las dos columnas iguales
d =["Case Number.2","Case Number.1"]
e =["href formula","href"]
limpito = limpito [limpito .columns.drop(d,e)]

# %%
limpito
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ... Fatal (Y/N)           Time         Species   \
# 0          Julie Wolfe    F  ...           N          18h00      White shark
# 1      Adyson McNeely     F  ...           N  14h00  -15h00              NaN
# 2          John Denges    M  ...           N          07h45              NaN
# 3                 male    M  ...           N            NaN        2 m shark
# 4       Gustavo Ramos     M  ...           N            NaN  Tiger shark, 3m
# ...                ...  ...  ...         ...            ...              ...
# 6307               NaN  NaN  ...         NaN            NaN              NaN
# 6308               NaN  NaN  ...         NaN            NaN              NaN
# 6309               NaN  NaN  ...         NaN            NaN              NaN
# 8702               NaN  NaN  ...         NaN            NaN              NaN
# 25722              NaN  NaN  ...         NaN            NaN              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 6307                              NaN                       NaN
# 6308                              NaN                       NaN
# 6309                              NaN                       NaN
# 8702                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href original order  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         6303.0
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         6302.0
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         6301.0
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         6300.0
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         6299.0
# ...                                                  ...            ...
# 6307                                                 NaN         6309.0
# 6308                                                 NaN         6310.0
# 6309                                                 NaN            NaN
# 8702                                                 NaN            NaN
# 25722                                                NaN            NaN
#
#       Unnamed: 22  Unnamed: 23
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 6307          NaN          NaN
# 6308          NaN          NaN
# 6309          NaN          NaN
# 8702          NaN          NaN
# 25722         NaN          NaN
#
# [6312 rows x 22 columns]

# %% [markdown]
# Veamos mas columnas duplicadas
#
# Unnamed: 22 y Unnamed: 23 parecen iguales

# %%
comparar("Unnamed: 22","Unnamed: 23")
# Out:
# True

# %% [markdown]
# Como son la misma eliminamos 1

# %%
limpito = limpito [limpito .columns.drop("Unnamed: 23")]
limpito
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 8702               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...  \
# 0          Julie Wolfe    F  ...
# 1      Adyson McNeely     F  ...
# 2          John Denges    M  ...
# 3                 male    M  ...
# 4       Gustavo Ramos     M  ...
# ...                ...  ...  ...
# 6307               NaN  NaN  ...
# 6308               NaN  NaN  ...
# 6309               NaN  NaN  ...
# 8702               NaN  NaN  ...
# 25722              NaN  NaN  ...
#
#                                                   Injury Fatal (Y/N)  \
# 0      No injury to occupant, outrigger canoe and pad...           N
# 1                             Minor injury to left thigh           N
# 2           Injury to left lower leg from surfboard skeg           N
# 3                              Minor injury to lower leg           N
# 4      Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                  ...         ...
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 8702                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#                 Time         Species           Investigator or Source  \
# 0              18h00      White shark                R. Collier, GSAF
# 1      14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2              07h45              NaN  K.McMurray, TrackingSharks.com
# 3                NaN        2 m shark                  B. Myatt, GSAF
# 4                NaN  Tiger shark, 3m                       A .Kipper
# ...              ...              ...                             ...
# 6307             NaN              NaN                             NaN
# 6308             NaN              NaN                             NaN
# 6309             NaN              NaN                             NaN
# 8702             NaN              NaN                             NaN
# 25722            NaN              NaN                             NaN
#
#                             pdf  \
# 0          2018.06.25-Wolfe.pdf
# 1        2018.06.18-McNeely.pdf
# 2         2018.06.09-Denges.pdf
# 3      2018.06.08-Arrawarra.pdf
# 4          2018.06.04-Ramos.pdf
# ...                         ...
# 6307                        NaN
# 6308                        NaN
# 6309                        NaN
# 8702                        NaN
# 25722                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href original order  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         6303.0
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         6302.0
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         6301.0
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         6300.0
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         6299.0
# ...                                                  ...            ...
# 6307                                                 NaN         6309.0
# 6308                                                 NaN         6310.0
# 6309                                                 NaN            NaN
# 8702                                                 NaN            NaN
# 25722                                                NaN            NaN
#
#        Unnamed: 22
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 6307           NaN
# 6308           NaN
# 6309           NaN
# 8702           NaN
# 25722          NaN
#
# [6312 rows x 21 columns]

# %% [markdown]
# Vemos los valores Nulos

# %%
df2.isnull().head()
# Out:
#    Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0        False  False  False  False    False  False     False     False
# 1        False  False  False  False    False  False     False     False
# 2        False  False  False  False    False  False     False     False
# 3        False  False  False  False    False  False     False     False
# 4        False  False  False  False    False  False     False     False
#
#     Name   Sex   ...  Species   Investigator or Source    pdf  href formula  \
# 0  False  False  ...     False                   False  False         False
# 1  False  False  ...      True                   False  False         False
# 2  False  False  ...      True                   False  False         False
# 3  False  False  ...     False                   False  False         False
# 4  False  False  ...     False                   False  False         False
#
#     href  Case Number.1  Case Number.2  original order  Unnamed: 22  \
# 0  False          False          False           False         True
# 1  False          False          False           False         True
# 2  False          False          False           False         True
# 3  False          False          False           False         True
# 4  False          False          False           False         True
#
#    Unnamed: 23
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#
# [5 rows x 24 columns]

# %% [markdown]
# Vemos los nulos

# %%
df.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#Elimino los valores NaN
limpito.drop( limpito[ limpito["Case Number"].isna() ].index , inplace=True)

limpito
# Out:
# /home/sergio/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6306            0          NaN     NaN         NaN        NaN
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 6306               NaN                             NaN          NaN
# 6307               NaN                             NaN          NaN
# 6308               NaN                             NaN          NaN
# 6309               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...  \
# 0          Julie Wolfe    F  ...
# 1      Adyson McNeely     F  ...
# 2          John Denges    M  ...
# 3                 male    M  ...
# 4       Gustavo Ramos     M  ...
# ...                ...  ...  ...
# 6306               NaN  NaN  ...
# 6307               NaN  NaN  ...
# 6308               NaN  NaN  ...
# 6309               NaN  NaN  ...
# 25722              NaN  NaN  ...
#
#                                                   Injury Fatal (Y/N)  \
# 0      No injury to occupant, outrigger canoe and pad...           N
# 1                             Minor injury to left thigh           N
# 2           Injury to left lower leg from surfboard skeg           N
# 3                              Minor injury to lower leg           N
# 4      Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                  ...         ...
# 6306                                                 NaN         NaN
# 6307                                                 NaN         NaN
# 6308                                                 NaN         NaN
# 6309                                                 NaN         NaN
# 25722                                                NaN         NaN
#
#                 Time         Species           Investigator or Source  \
# 0              18h00      White shark                R. Collier, GSAF
# 1      14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2              07h45              NaN  K.McMurray, TrackingSharks.com
# 3                NaN        2 m shark                  B. Myatt, GSAF
# 4                NaN  Tiger shark, 3m                       A .Kipper
# ...              ...              ...                             ...
# 6306             NaN              NaN                             NaN
# 6307             NaN              NaN                             NaN
# 6308             NaN              NaN                             NaN
# 6309             NaN              NaN                             NaN
# 25722            NaN              NaN                             NaN
#
#                             pdf  \
# 0          2018.06.25-Wolfe.pdf
# 1        2018.06.18-McNeely.pdf
# 2         2018.06.09-Denges.pdf
# 3      2018.06.08-Arrawarra.pdf
# 4          2018.06.04-Ramos.pdf
# ...                         ...
# 6306                        NaN
# 6307                        NaN
# 6308                        NaN
# 6309                        NaN
# 25722                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6306                                                 NaN
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 25722                                                NaN
#
#                                                     href original order  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...         6303.0
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...         6302.0
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...         6301.0
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...         6300.0
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...         6299.0
# ...                                                  ...            ...
# 6306                                                 NaN         6308.0
# 6307                                                 NaN         6309.0
# 6308                                                 NaN         6310.0
# 6309                                                 NaN            NaN
# 25722                                                NaN            NaN
#
#        Unnamed: 22
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 6306           NaN
# 6307           NaN
# 6308           NaN
# 6309           NaN
# 25722          NaN
#
# [6310 rows x 21 columns]

# %%
limpito.drop( limpito[ limpito["Year"].isna() ].index , inplace=True)
limpito
# Out:
# /home/sergio/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...  \
# 0               Julie Wolfe    F  ...
# 1           Adyson McNeely     F  ...
# 2               John Denges    M  ...
# 3                      male    M  ...
# 4            Gustavo Ramos     M  ...
# ...                     ...  ...  ...
# 6297                   male    M  ...
# 6298                  Ahmun    M  ...
# 6299  Coast Guard personnel    M  ...
# 6300        Jules Patterson    M  ...
# 6301                   male    M  ...
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href original order  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         6303.0
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         6302.0
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         6301.0
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         6300.0
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         6299.0
# ...                                                 ...            ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...            6.0
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...            5.0
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...            4.0
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...            3.0
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...            2.0
#
#       Unnamed: 22
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6297          NaN
# 6298          NaN
# 6299          NaN
# 6300          NaN
# 6301          NaN
#
# [6299 rows x 21 columns]

# %%
limpito["Year"].fillna("")
limpito["Year"].value_counts().sort_values(ascending=False)
limpito["Year"].isnull().sum()
# Out:
# 0

# %%
limpito["Case Number"].value_counts().sort_values(ascending=False)
# Out:
# 1915.07.06.a.R    2
# 1990.05.10        2
# 1962.06.11.b      2
# 1907.10.16.R      2
# 2013.10.05        2
#                  ..
# 1823.12.30.R      1
# 1879.03.19        1
# 1894.06.15.b.R    1
# 1979.09.14        1
# 1962.10.06        1
# Name: Case Number, Length: 6283, dtype: int64

# %%
#Creo la funcion borrar filas
def borrarfilas(x):
    for e in x:
        if e== 0 :
            return (x.drop(e))
        elif e == None:      
            pass
borrarfilas(limpito["Case Number"])

# %%
df_clean=limpito[["Case Number","Year"]]

df_clean
# Out:
#      Case Number    Year
# 0     2018.06.25  2018.0
# 1     2018.06.18  2018.0
# 2     2018.06.09  2018.0
# 3     2018.06.08  2018.0
# 4     2018.06.04  2018.0
# ...          ...     ...
# 6297     ND.0005     0.0
# 6298     ND.0004     0.0
# 6299     ND.0003     0.0
# 6300     ND.0002     0.0
# 6301     ND.0001     0.0
#
# [6299 rows x 2 columns]

# %%
#Miro los valores de Year
df_clean.Year.value_counts().reset_index().sort_values("index").set_index('index').Year
# Out:
# index
# 0.0       125
# 5.0         1
# 77.0        1
# 500.0       1
# 1543.0      1
#          ...
# 2014.0    127
# 2015.0    143
# 2016.0    130
# 2017.0    136
# 2018.0     53
# Name: Year, Length: 249, dtype: int64

# %%
#rename a siglo20 para coger solo los valores que entran en esas fechas
siglo20=df_clean["Year"]   
def Siglos20(x):
    for e in x:
        if e>=1900:
            pass 
        else:    
            return (x.drop(e))
         
Siglos20(siglo20)


df_clean["Decada"] = pd.cut(df_clean.Year,bins=range(1899,2019,10),labels=range(1900,2020,10))
print(list(df_clean["Decada"] ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-6e7da6f0239a> in <module>
#      12
#      13 df_clean["Decada"] = pd.cut(df_clean.Year,bins=range(1899,2019,10),
# ---> 14                            labels=range(1900,2020,10))
#      15 print(list(df_clean["Decada"] ))
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     409             if len(labels) != len(bins) - 1:
#     410                 raise ValueError(
# --> 411                     "Bin labels must be one fewer than the number of bin edges"
#     412                 )
#     413
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
def set_value(row_number, assigned_value): 
    return assigned_value[row_number] 

df_clean=limpito[["Case Number","Year"]]
df_clean.sort_values('Year',ascending=False)
df["Decada"] = df['Year'].apply(set_value, df['Year']) 
#df_clean["Decada"] = pd.cut(df_clean.Year,bins=[siglo20],labels=range(1900,2020,10))
print(df_clean["Decada"] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-1fb7fd144c83> in <module>
#       1 df_clean=limpito[["Case Number","Year"]]
#       2 df_clean.sort_values('Year',ascending=False)
# ----> 3 df["Decada"] = df['Year'].apply(set_value, args =(event_dictionary, ))
#       4 #df_clean["Decada"] = pd.cut(df_clean.Year,bins=[siglo20],labels=range(1900,2020,10))
#       5 print(df_clean["Decada"] )
#
# NameError: name 'set_value' is not defined

# %%
df_clean=limpito[["Case Number","Decad"]]
# %matplotlib inline

# %%
print(list(df_clean["Year"]))
